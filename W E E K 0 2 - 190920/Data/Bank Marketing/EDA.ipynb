# %%
# import libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# load dataset
path = '/content/drive/My Drive/HK7/Seminar/W E E K 0 2 - 190920/Data/Bank Marketing/bank-additional-full.csv'
data = pd.read_csv(path, sep = ';')

# %%
# data sample inspection
data.head()
# Out:
#    age        job  marital  ... euribor3m nr.employed   y
# 0   56  housemaid  married  ...     4.857      5191.0  no
# 1   57   services  married  ...     4.857      5191.0  no
# 2   37   services  married  ...     4.857      5191.0  no
# 3   40     admin.  married  ...     4.857      5191.0  no
# 4   56   services  married  ...     4.857      5191.0  no
#
# [5 rows x 21 columns]

# %%
numeric_features = data[['age', 'duration', 'campaign', 'pdays', 'previous', 'emp.var.rate', 'cons.price.idx', 'cons.conf.idx', 'euribor3m', 'nr.employed']]

categorical_features=data[['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact', 'month', 'day_of_week', 'poutcome', 'y']]

# %%
numeric_features
# Out:
#        age  duration  campaign  ...  cons.conf.idx  euribor3m  nr.employed
# 0       56       261         1  ...          -36.4      4.857       5191.0
# 1       57       149         1  ...          -36.4      4.857       5191.0
# 2       37       226         1  ...          -36.4      4.857       5191.0
# 3       40       151         1  ...          -36.4      4.857       5191.0
# 4       56       307         1  ...          -36.4      4.857       5191.0
# ...    ...       ...       ...  ...            ...        ...          ...
# 41183   73       334         1  ...          -50.8      1.028       4963.6
# 41184   46       383         1  ...          -50.8      1.028       4963.6
# 41185   56       189         2  ...          -50.8      1.028       4963.6
# 41186   44       442         1  ...          -50.8      1.028       4963.6
# 41187   74       239         3  ...          -50.8      1.028       4963.6
#
# [41188 rows x 10 columns]

# %%
categorical_features
# Out:
#                job  marital            education  ... day_of_week     poutcome    y
# 0        housemaid  married             basic.4y  ...         mon  nonexistent   no
# 1         services  married          high.school  ...         mon  nonexistent   no
# 2         services  married          high.school  ...         mon  nonexistent   no
# 3           admin.  married             basic.6y  ...         mon  nonexistent   no
# 4         services  married          high.school  ...         mon  nonexistent   no
# ...            ...      ...                  ...  ...         ...          ...  ...
# 41183      retired  married  professional.course  ...         fri  nonexistent  yes
# 41184  blue-collar  married  professional.course  ...         fri  nonexistent   no
# 41185      retired  married    university.degree  ...         fri  nonexistent   no
# 41186   technician  married  professional.course  ...         fri  nonexistent  yes
# ...

# %%
# feature distribution
for col in data.columns:
  print(col)
  display(data[col].value_counts())
  print()
  print()
# Out:
# age
# 31    1947
# 32    1846
# 33    1833
# 36    1780
# 35    1759
#       ...
# 89       2
# 91       2
# 87       1
# 94       1
# 95       1
# Name: age, Length: 78, dtype: int64
# job
# admin.           10422
# blue-collar       9254
# technician        6743
# services          3969
# management        2924
# retired           1720
# entrepreneur      1456
# self-employed     1421
# housemaid         1060
# unemployed        1014
# student            875
# unknown            330
# Name: job, dtype: int64
# marital
# married     24928
# single      11568
# divorced     4612
# unknown        80
# Name: marital, dtype: int64
# education
# university.degree      12168
# high.school             9515
# basic.9y                6045
# professional.course     5243
# basic.4y                4176
# basic.6y                2292
# unknown                 1731
# illiterate                18
# Name: education, dtype: int64
# default
# no         32588
# unknown     8597
# yes            3
# ...

# %% [markdown]
# ### Numeric features

# %%
# primary statistic
data.describe()
# Out:
#                age      duration  ...     euribor3m   nr.employed
# count  41188.00000  41188.000000  ...  41188.000000  41188.000000
# mean      40.02406    258.285010  ...      3.621291   5167.035911
# std       10.42125    259.279249  ...      1.734447     72.251528
# min       17.00000      0.000000  ...      0.634000   4963.600000
# 25%       32.00000    102.000000  ...      1.344000   5099.100000
# 50%       38.00000    180.000000  ...      4.857000   5191.000000
# 75%       47.00000    319.000000  ...      4.961000   5228.100000
# max       98.00000   4918.000000  ...      5.045000   5228.100000
#
# [8 rows x 10 columns]

# %%
for col in numeric_features:
  print(col.upper())
  counts = numeric_features[col].value_counts()
  percent100 = numeric_features[col].value_counts(normalize=True).mul(100).round(1).astype(str) + '%'
  col=pd.DataFrame({'counts': counts, 'Percent': percent100})
  print(col)
  print()
  print()
# Out:
# AGE
#     counts Percent
# 31    1947    4.7%
# 32    1846    4.5%
# 33    1833    4.5%
# 36    1780    4.3%
# 35    1759    4.3%
# ..     ...     ...
# 89       2    0.0%
# 91       2    0.0%
# 87       1    0.0%
# 94       1    0.0%
# 95       1    0.0%
#
# [78 rows x 2 columns]
#
#
# DURATION
#       counts Percent
# 85       170    0.4%
# 90       170    0.4%
# 136      168    0.4%
# 73       167    0.4%
# 124      164    0.4%
# ...      ...     ...
# 1108       1    0.0%
# 980        1    0.0%
# 4918       1    0.0%
# 2453       1    0.0%
# 2015       1    0.0%
#
# [1544 rows x 2 columns]
#
#
# CAMPAIGN
#     counts Percent
# 1    17642   42.8%
# 2    10570   25.7%
# 3     5341   13.0%
# 4     2651    6.4%
# 5     1599    3.9%
# 6      979    2.4%
# 7      629    1.5%
# 8      400    1.0%
# 9      283    0.7%
# 10     225    0.5%
# 11     177    0.4%
# 12     125    0.3%
# 13      92    0.2%
# 14      69    0.2%
# 17      58    0.1%
# 15      51    0.1%
# 16      51    0.1%
# ...

# %%
# numeric features distribution histograms
numeric_features.hist(figsize=[10,10])
plt.suptitle("Numeric feature distribution")
plt.show()

# %%
# Outlier
for col in numeric_features:
  sns.boxplot(x=col,y='y',data=data)
  plt.show()

# %%
# PDF
for col in numeric_features:
  sns.FacetGrid(data,hue="y",height = 5).map(sns.distplot, col). add_legend()
  plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
# scatter plot
col = numeric_features.columns
for i in range(0,9):
  for j in range(-1,-10,-1):
    sns.set_style("whitegrid")
    sns.FacetGrid(data, hue = 'y', height =5).map(plt.scatter,col[i],col[j]).add_legend()
    plt.show()
    print()
    print()

# %%
# correlation matrix
corr =  numeric_features.corr()
# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(9, 7))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(240, 10, n=9)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .8})
plt.show()

# %% [markdown]
# ###Categorical features

# %%
for col in categorical_features:
  print(col.upper())
  counts = categorical_features[col].value_counts()
  percent100 = categorical_features[col].value_counts(normalize=True).mul(100).round(1).astype(str) + '%'
  col=pd.DataFrame({'counts': counts, 'Percent': percent100})
  print(col)
  print()
  print()
# Out:
# JOB
#                counts Percent
# admin.          10422   25.3%
# blue-collar      9254   22.5%
# technician       6743   16.4%
# services         3969    9.6%
# management       2924    7.1%
# retired          1720    4.2%
# entrepreneur     1456    3.5%
# self-employed    1421    3.5%
# housemaid        1060    2.6%
# unemployed       1014    2.5%
# student           875    2.1%
# unknown           330    0.8%
#
#
# MARITAL
#           counts Percent
# married    24928   60.5%
# single     11568   28.1%
# divorced    4612   11.2%
# unknown       80    0.2%
#
#
# EDUCATION
#                      counts Percent
# university.degree     12168   29.5%
# high.school            9515   23.1%
# basic.9y               6045   14.7%
# professional.course    5243   12.7%
# basic.4y               4176   10.1%
# basic.6y               2292    5.6%
# unknown                1731    4.2%
# illiterate               18    0.0%
#
#
# DEFAULT
#          counts Percent
# no        32588   79.1%
# ...

# %%
# Encode
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

col = categorical_features.columns
for i in col:
  name = i+'_le'
  data[name] = le.fit_transform(data[i])

data
# Out:
#        age          job  marital  ... day_of_week_le poutcome_le y_le
# 0       56    housemaid  married  ...              1           1    0
# 1       57     services  married  ...              1           1    0
# 2       37     services  married  ...              1           1    0
# 3       40       admin.  married  ...              1           1    0
# 4       56     services  married  ...              1           1    0
# ...    ...          ...      ...  ...            ...         ...  ...
# 41183   73      retired  married  ...              0           1    1
# 41184   46  blue-collar  married  ...              0           1    0
# 41185   56      retired  married  ...              0           1    0
# 41186   44   technician  married  ...              0           1    1
# 41187   74      retired  married  ...              0           0    0
#
# [41188 rows x 32 columns]

# %%
categorical_features_le = data.loc[:, 'job_le':'y_le']

categorical_features_le.hist(figsize=[10,10])
plt.suptitle("Categorical feature distribution")
plt.show()

# %%
# correlation matrix
corr =  categorical_features_le.corr()
# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(240, 10, n=9)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .8})
plt.show()

# %% [markdown]
# ###Link
# https://growingdata.com.au/a-guided-introduction-to-exploratory-data-analysis-eda-using-python/
#
# https://www.kaggle.com/henriqueyamahata/bank-marketing-classification-roc-f1-recall
